# %% [markdown]
# # Red Wine Quality Analysis
#
# This notebook loads the documented UCI dataset, summarizes the target, and generates the project's EDA figures.

# %%
from red_wine_quality.data import load_data
import matplotlib.pyplot as plt
import seaborn as sns

df = load_data()
df.describe().T

# %%
sns.histplot(df, x='quality', discrete=True)
plt.title('Red wine quality distribution')
plt.show()
